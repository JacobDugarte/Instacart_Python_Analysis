# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Importing Data

# %% [markdown]
# ### Importing Data set orders_checked.csv

# %%
# Creating a Path
path = r'/Users/jacob/Desktop/Instacart Basket Analysis'

# %%
# Importing orders.csv data set
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_checked.csv'), index_col = False)

# %%
# Checking the dimensions of the orders.csv dataframe
df_ords.shape
# Out:
# (3421083, 8)

# %% [markdown]
# ### Importing Data Set orders_products_prior.csv

# %%
df_ords_prior = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders_products_prior.csv'), index_col = False)

# %%
# Checking the dimensions of the new dataframe
df_ords_prior.shape
# Out:
# (32434489, 4)

# %% [markdown]
# # Merging the two Dataframes df_ords and df_ords_prior

# %%
# Check the Dataframe df_ords_prior
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
# Check the Dataframe df_ords
df_ords.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             1           1   2398795        1             2
# 2             2           2    473747        1             3
# 3             3           3   2254736        1             4
# 4             4           4    431534        1             5
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order
# 0                   2                  8                     NaN
# 1                   3                  7                    15.0
# 2                   3                 12                    21.0
# 3                   4                  7                    29.0
# 4                   4                 15                    28.0

# %%
# Checking the dimensions of the orders.csv dataframe
df_ords.shape
# Out:
# (3421083, 8)

# %%
# Checking the dimensions of the new dataframe
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
# Merging the two dataframes
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
# Checking the output
df_merged_large.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             0           0   2539329        1             1
# 2             0           0   2539329        1             1
# 3             0           0   2539329        1             1
# 4             0           0   2539329        1             1
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                   2                  8                     NaN         196
# 1                   2                  8                     NaN       14084
# 2                   2                  8                     NaN       12427
# 3                   2                  8                     NaN       26088
# 4                   2                  8                     NaN       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# 1                  2          0   both
# ...

# %%
# Checking Frequency
df_merged_large['_merge'].value_counts()
# Out:
# _merge
# both          32434489
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
# check for null values df_merged_large
df_merged_large.isnull().sum()
# Out:
# Unnamed: 0.1                    0
# Unnamed: 0                      0
# order_id                        0
# user_id                         0
# order_number                    0
# orders_day_of_week              0
# order_hour_of_day               0
# days_since_prior_order    2078068
# product_id                      0
# add_to_cart_order               0
# reordered                       0
# _merge                          0
# dtype: int64

# %%
crosstab = pd.crosstab(df_merged_large['days_since_prior_order'], df_merged_large['order_number'], dropna = False)

# %% [markdown]
# ### From the checks you conducted on your Instacart data, you know that there are some missing values in the “days_since_prior_order” column. You can only assume that these missing values were caused by the fact that there can’t be any days before a first order, as this is what makes the most sense. Using the head() and tail() functions also confirms this assumption. However, you still can’t be sure that all the missing values in this column exist for this reason.
#
# ### A better way to check this would be to create a crosstab between the “days_since_prior_order” column and the “order_number” column. Then, if all the missing values from “days_since_prior_order” fall where the order number is equal to 1, you can consider your hypothesis confirmed and move on with the rest of your analysis.

# %%
crosstab
# Out:
# order_number            1       2       3       4       5       6       7   \
# days_since_prior_order
# 0.0                      0   20564   20452   17999   16450   16063   14396
# 1.0                      0   31693   29974   28028   27109   25548   25013
# 2.0                      0   46492   46301   43935   40761   40944   38139
# 3.0                      0   61702   63454   60047   57933   56218   52915
# 4.0                      0   76796   78925   73613   70593   66631   62458
# 5.0                      0   89104   91826   86576   81936   77648   73633
# 6.0                      0  120789  123007  114760  106863  100843   96041
# 7.0                      0  184983  181832  167759  157602  143765  137805
# 8.0                      0  112446  110850  102311   95046   87709   81714
# 9.0                      0   73740   75438   68589   65108   58983   54853
# 10.0                     0   62085   62509   57733   51957   49514   43764
# ...

# %% [markdown]
# ### The table this creates will be stored in the object crosstab. Considering its size, it may be cumbersome to view directly in Python. In cases like this, you can copy the table straight to your clipboard, allowing you to then paste it into Excel for easy viewing. To do so, type the following command:

# %%
crosstab.to_clipboard()

# %% [markdown]
# ## How to paste it in excel???

# %% [markdown]
# # Exporting the data

# %%
# Export data to pkl

df_merged_large.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.pkl'))

# %% [markdown]
# # Task 4.6

# %% [markdown]
# ## Importing Data

# %% [markdown]
# ### Importing Data set products_checked.csv

# %%
# Importing products_checked.csv data set
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'), index_col = False)

# %%
# Checking the output df_prods
df_prods.shape
# Out:
# (49672, 6)

# %%
# Importing orders_products_combined.pkl dataframe
df_ords_prods_combined = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
# Checking the output df_ords_prods
df_ords_prods_combined.shape
# Out:
# (32434489, 12)

# %%
# Checking the columns on df_ords_prods_combined
df_ords_prods_combined.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             0           0   2539329        1             1
# 2             0           0   2539329        1             1
# 3             0           0   2539329        1             1
# 4             0           0   2539329        1             1
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                   2                  8                     NaN         196
# 1                   2                  8                     NaN       14084
# 2                   2                  8                     NaN       12427
# 3                   2                  8                     NaN       26088
# 4                   2                  8                     NaN       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# 1                  2          0   both
# ...

# %%
# Checking the columns on df_prods
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
# check for null values df_prods
df_prods.isnull().sum()
# Out:
# Unnamed: 0       0
# product_id       0
# product_name     0
# aisle_id         0
# department_id    0
# prices           0
# dtype: int64

# %% [markdown]
# ## Question 5: Determine a suitable way to combine the orders_products_combined dataframe with your products data set

# %%
# Drop unnamed columns in df_prods  
df_prods = df_prods.drop(columns = ['Unnamed: 0'])

# %%
# Drop unnamed columns in df_ords_prods_combined  
df_ords_prods_combined = df_ords_prods_combined.drop(columns = ['Unnamed: 0', 'Unnamed: 0.1', '_merge'])

# %%
# Checking the output df_prods
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
# Checking the output df_ords_prods_combined
df_ords_prods_combined.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0

# %% [markdown]
# ### A suitable way to merge the two dataframes df_prods and df_ords_prods_combined is by the column product_id, found in both dataframes

# %%
# Merging df_the ords_prods_combined with the df_prods through the product_id Column
df_ords_prods_merged = df_ords_prods_combined.merge(df_prods, on = 'product_id', indicator = True)

# %% [markdown]
# ## Question 6: Confirm the results of the merge using the merge flag.

# %%
# Checking df_ords_prods_merged dataframe
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge
# 0         Soda        77              7     9.0   both
# ...

# %%
# Checking the values in the _merge column
df_ords_prods_merged['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
# Checking the merged shape
df_ords_prods_merged.shape
# Out:
# (32404859, 14)

# %%
# check for null values df_ords_prods_merged
df_ords_prods_merged.isnull().sum()
# Out:
# order_id                        0
# user_id                         0
# order_number                    0
# orders_day_of_week              0
# order_hour_of_day               0
# days_since_prior_order    2076096
# product_id                      0
# add_to_cart_order               0
# reordered                       0
# product_name                    0
# aisle_id                        0
# department_id                   0
# prices                          0
# _merge                          0
# dtype: int64

# %% [markdown]
# ## Question 7: Export the newly created dataframe as orders_products_merged

# %%
# Exporting the newly merged dataframe using pickle format
df_ords_prods_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
